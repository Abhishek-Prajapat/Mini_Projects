# %%
import sys
import os

# sys.path.append('/content/drive/MyDrive/internship assignment/src')

# %%
# !chmod 755 /content/drive/MyDrive/internship_assignment/src/runColab.sh

# %%
# !pip install pretrainedmodels
# !pip install albumentations

# %%
# !python /content/drive/MyDrive/internship_assignment/src/create_folds.py

# %%
# !sh /content/drive/MyDrive/internship_assignment/src/runColab.sh
# Out:
# 2021-06-01 00:26:53.640071: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch: 0, train_loss: 0.7117317914962769, validation_loss: 0.7233988046646118
# Epoch: 1, train_loss: 0.6144113540649414, validation_loss: 0.8229707479476929
# Epoch: 2, train_loss: 0.5996498465538025, validation_loss: 0.6718865036964417
# Epoch: 3, train_loss: 0.5230033993721008, validation_loss: 0.7077162265777588
# ...

# %%
while True:
  pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-648a2bab0435> in <module>()
#       1 while True:
# ----> 2   pass
#
# KeyboardInterrupt:
